# %% [markdown]
# ## KANELLAKI MARIA ANNA

# %%
import os
import pandas as pd
import sys
import numpy as np
import gensim
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# # Ready data

# %%
path = 'fulltext/data'
id = 0

alldata = open('fulltext/data/all_set.tsv', "wt")
csv.writer(alldata, delimiter='\t').writerow(['id', 'title', 'content', 'category'])

tsv1 = open('fulltext/data/train_set.tsv', "wt")
csv.writer(tsv1, delimiter='\t').writerow(['id', 'title', 'content', 'category'])

tsv2 = open('fulltext/data/test_set.tsv', "wt")
csv.writer(tsv2, delimiter='\t').writerow(['id', 'title', 'content'])
# Out:
# 18

# %% [markdown]
# ## Adds 80% of each dirs files in train and 20 in set

# %%
for dir in os.listdir(path):
    if os.path.isdir(path+'/'+dir):
        num_files = len([file for file in os.listdir(path+'/'+dir)])
        counter = 0
        percent = num_files* 80/100
        for file in os.listdir(path+'/'+dir):
            counter += 1
            
            f = open(path+'/'+dir+'/'+file, 'r', encoding='ISO-8859-1')
            title = f.readline()
            content = f.read()
            csv.writer(alldata, delimiter='\t').writerow([id, str(title), content, dir])
            
            if counter < percent:
                csv.writer(tsv1, delimiter='\t').writerow([id, str(title), content, dir])
            else:
                csv.writer(tsv2, delimiter='\t').writerow([id, str(title), content])

            
            id += 1

# %% [markdown]
# ## Create dataframes from the tsvs

# %%
df_all = pd.DataFrame()
df_all = pd.read_csv(path+'/all_set.tsv', delimiter='\t', encoding='utf-8-sig')
df_all
# Out:
#         id                                title  \
# 0        0  Bargain calls widen Softbank loss\n
# 1        1    S&N extends Indian beer venture\n
# 2        2   News Corp makes $5.4bn Fox offer\n
# 3        3    China now top trader with Japan\n
# 4        4   Asian quake hits European shares\n
# ...    ...                                  ...
# 2220  2220         Concerns over Windows ATMs\n
# 2221  2221  Britons growing 'digitally obese'\n
# 2222  2222    Online games play with politics\n
# 2223  2223    Mobiles rack up 20 years of use\n
# 2224  2224  Nintendo handheld given Euro date\n
#
#                                                 content  category
# 0     \nJapanese communications firm Softbank has wi...  business
# 1     \nThe UK's biggest brewer, Scottish and Newcas...  business
# 2     \nNews Corporation is seeking to buy out minor...  business
# 3     \nChina overtook the US to become Japan's bigg...  business
# 4     \nShares in Europe's leading reinsurers and tr...  business
# ...                                                 ...       ...
# 2220  \nCash machine networks could soon be more sus...      tech
# 2221  \nGadget lovers are so hungry for digital data...      tech
# 2222  \nAfter bubbling under for some time, online g...      tech
# 2223  \nMobile phones in the UK are celebrating thei...      tech
# 2224  \nNintendo's new handheld console, the DS, wil...      tech
#
# [2225 rows x 4 columns]

# %%
df_tr = pd.DataFrame()
df_tr = pd.read_csv(path+'/train_set.tsv', delimiter='\t', encoding='utf-8-sig')
df_tr
# Out:
#         id                                title  \
# 0        0  Bargain calls widen Softbank loss\n
# 1        1    S&N extends Indian beer venture\n
# 2        2   News Corp makes $5.4bn Fox offer\n
# 3        3    China now top trader with Japan\n
# 4        4   Asian quake hits European shares\n
# ...    ...                                  ...
# 1771  2139   T-Mobile bets on 'pocket office'\n
# 1772  2140           Cheaper chip for mobiles\n
# 1773  2141   Hollywood campaign hits websites\n
# 1774  2142    Sony wares win innovation award\n
# 1775  2143    Consumers 'snub portable video'\n
#
#                                                 content  category
# 0     \nJapanese communications firm Softbank has wi...  business
# 1     \nThe UK's biggest brewer, Scottish and Newcas...  business
# 2     \nNews Corporation is seeking to buy out minor...  business
# 3     \nChina overtook the US to become Japan's bigg...  business
# 4     \nShares in Europe's leading reinsurers and tr...  business
# ...                                                 ...       ...
# 1771  \nT-Mobile has launched its latest "pocket off...      tech
# 1772  \nA mobile phone chip which combines a modem a...      tech
# 1773  \nMovie studio efforts to stop pirated films b...      tech
# 1774  \nSony has taken the prize for top innovator a...      tech
# 1775  \nConsumers want music rather than movies whil...      tech
#
# [1776 rows x 4 columns]

# %%
df_tst = pd.DataFrame()
df_tst = pd.read_csv(path+'/test_set.tsv', delimiter='\t', encoding='utf-8-sig')
df_tst
# Out:
#        id                                title  \
# 0     407    Steel firm 'to cut' 45,000 jobs\n
# 1     408     Europe asks Asia for euro help\n
# 2     409    US Ahold suppliers face charges\n
# 3     410  McDonald's boss Bell dies aged 44\n
# 4     411  US Airways staff agree to pay cut\n
# ..    ...                                  ...
# 444  2220         Concerns over Windows ATMs\n
# 445  2221  Britons growing 'digitally obese'\n
# 446  2222    Online games play with politics\n
# 447  2223    Mobiles rack up 20 years of use\n
# 448  2224  Nintendo handheld given Euro date\n
#
#                                                content
# 0    \nMittal Steel, one of the world's largest ste...
# 1    \nEuropean leaders say Asian states must let t...
# 2    \nUS prosecutors have charged nine food suppli...
# 3    \nCharlie Bell, the straight-talking former he...
# 4    \nA union representing 5,200 flight attendants...
# ..                                                 ...
# 444  \nCash machine networks could soon be more sus...
# 445  \nGadget lovers are so hungry for digital data...
# 446  \nAfter bubbling under for some time, online g...
# 447  \nMobile phones in the UK are celebrating thei...
# 448  \nNintendo's new handheld console, the DS, wil...
#
# [449 rows x 3 columns]

# %% [markdown]
# # 1. Wordclouds

# %%
from wordcloud import WordCloud, STOPWORDS
stop = ["Mr", "will", "one", "said", "year", "new"]+list(STOPWORDS)

# %% [markdown]
# ## Business WordCloud

# %%
text = " ".join(cont for cont in df_all.content[df_all.category == 'business'])
wordcloud = WordCloud(stopwords=stop).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Entertainment WordCloud

# %%
text = " ".join(cont for cont in df_all.content[df_all.category == 'entertainment'])
wordcloud = WordCloud(stopwords=stop, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Politics WordCloud

# %%
text = " ".join(cont for cont in df_all.content[df_all.category == 'politics'])
wordcloud = WordCloud(stopwords=stop).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Sport WordCloud

# %%
text = " ".join(cont for cont in df_all.content[df_all.category == 'sport'])
wordcloud = WordCloud(stopwords=stop, background_color="white").generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Tech WordCloud

# %%
text = " ".join(cont for cont in df_all.content[df_all.category == 'tech'])
wordcloud = WordCloud(stopwords=stop).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # 2. Classification

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
import re
import string
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /home/marianna/nltk_data...
#        |   Package abc is already up-to-date!
#        | Downloading package alpino to /home/marianna/nltk_data...
#        |   Package alpino is already up-to-date!
#        | Downloading package biocreative_ppi to
#        |     /home/marianna/nltk_data...
#        |   Package biocreative_ppi is already up-to-date!
#        | Downloading package brown to /home/marianna/nltk_data...
#        |   Package brown is already up-to-date!
#        | Downloading package brown_tei to /home/marianna/nltk_data...
#        |   Package brown_tei is already up-to-date!
#        | Downloading package cess_cat to /home/marianna/nltk_data...
#        |   Package cess_cat is already up-to-date!
#        | Downloading package cess_esp to /home/marianna/nltk_data...
#        |   Package cess_esp is already up-to-date!
#        | Downloading package chat80 to /home/marianna/nltk_data...
#        |   Package chat80 is already up-to-date!
#        | Downloading package city_database to
#        |     /home/marianna/nltk_data...
#        |   Package city_database is already up-to-date!
#        | Downloading package cmudict to /home/marianna/nltk_data...
#        |   Package cmudict is already up-to-date!
#        | Downloading package comparative_sentences to
#        |     /home/marianna/nltk_data...
#        |   Package comparative_sentences is already up-to-date!
#        | Downloading package comtrans to /home/marianna/nltk_data...
#        |   Package comtrans is already up-to-date!
#        | Downloading package conll2000 to /home/marianna/nltk_data...
#        |   Package conll2000 is already up-to-date!
#        | Downloading package conll2002 to /home/marianna/nltk_data...
#        |   Package conll2002 is already up-to-date!
#        | Downloading package conll2007 to /home/marianna/nltk_data...
#        |   Package conll2007 is already up-to-date!
#        | Downloading package crubadan to /home/marianna/nltk_data...
#        |   Package crubadan is already up-to-date!
#        | Downloading package dependency_treebank to
#        |     /home/marianna/nltk_data...
#        |   Package dependency_treebank is already up-to-date!
#        | Downloading package dolch to /home/marianna/nltk_data...
#        |   Package dolch is already up-to-date!
#        | Downloading package europarl_raw to
#        |     /home/marianna/nltk_data...
#        |   Package europarl_raw is already up-to-date!
#        | Downloading package floresta to /home/marianna/nltk_data...
#        |   Package floresta is already up-to-date!
#        | Downloading package framenet_v15 to
#        |     /home/marianna/nltk_data...
#        |   Package framenet_v15 is already up-to-date!
#        | Downloading package framenet_v17 to
#        |     /home/marianna/nltk_data...
#        |   Package framenet_v17 is already up-to-date!
#        | Downloading package gazetteers to /home/marianna/nltk_data...
#        |   Package gazetteers is already up-to-date!
#        | Downloading package genesis to /home/marianna/nltk_data...
#        |   Package genesis is already up-to-date!
#        | Downloading package gutenberg to /home/marianna/nltk_data...
#        |   Package gutenberg is already up-to-date!
#        | Downloading package ieer to /home/marianna/nltk_data...
#        |   Package ieer is already up-to-date!
#        | Downloading package inaugural to /home/marianna/nltk_data...
#        |   Package inaugural is already up-to-date!
#        | Downloading package indian to /home/marianna/nltk_data...
#        |   Package indian is already up-to-date!
#        | Downloading package jeita to /home/marianna/nltk_data...
#        |   Package jeita is already up-to-date!
#        | Downloading package kimmo to /home/marianna/nltk_data...
#        |   Package kimmo is already up-to-date!
#        | Downloading package knbc to /home/marianna/nltk_data...
#        |   Package knbc is already up-to-date!
#        | Downloading package lin_thesaurus to
#        |     /home/marianna/nltk_data...
#        |   Package lin_thesaurus is already up-to-date!
#        | Downloading package mac_morpho to /home/marianna/nltk_data...
#        |   Package mac_morpho is already up-to-date!
#        | Downloading package machado to /home/marianna/nltk_data...
#        |   Package machado is already up-to-date!
#        | Downloading package masc_tagged to
#        |     /home/marianna/nltk_data...
#        |   Package masc_tagged is already up-to-date!
#        | Downloading package moses_sample to
#        |     /home/marianna/nltk_data...
#        |   Package moses_sample is already up-to-date!
#        | Downloading package movie_reviews to
#        |     /home/marianna/nltk_data...
#        |   Package movie_reviews is already up-to-date!
#        | Downloading package names to /home/marianna/nltk_data...
#        |   Package names is already up-to-date!
#        | Downloading package nombank.1.0 to
#        |     /home/marianna/nltk_data...
#        |   Package nombank.1.0 is already up-to-date!
#        | Downloading package nps_chat to /home/marianna/nltk_data...
#        |   Package nps_chat is already up-to-date!
#        | Downloading package omw to /home/marianna/nltk_data...
#        |   Package omw is already up-to-date!
#        | Downloading package opinion_lexicon to
#        |     /home/marianna/nltk_data...
#        |   Package opinion_lexicon is already up-to-date!
#        | Downloading package paradigms to /home/marianna/nltk_data...
#        |   Package paradigms is already up-to-date!
#        | Downloading package pil to /home/marianna/nltk_data...
#        |   Package pil is already up-to-date!
#        | Downloading package pl196x to /home/marianna/nltk_data...
#        |   Package pl196x is already up-to-date!
#        | Downloading package ppattach to /home/marianna/nltk_data...
#        |   Package ppattach is already up-to-date!
#        | Downloading package problem_reports to
#        |     /home/marianna/nltk_data...
#        |   Package problem_reports is already up-to-date!
#        | Downloading package propbank to /home/marianna/nltk_data...
#        |   Package propbank is already up-to-date!
#        | Downloading package ptb to /home/marianna/nltk_data...
#        |   Package ptb is already up-to-date!
#        | Downloading package product_reviews_1 to
#        |     /home/marianna/nltk_data...
#        |   Package product_reviews_1 is already up-to-date!
#        | Downloading package product_reviews_2 to
#        |     /home/marianna/nltk_data...
#        |   Package product_reviews_2 is already up-to-date!
#        | Downloading package pros_cons to /home/marianna/nltk_data...
#        |   Package pros_cons is already up-to-date!
#        | Downloading package qc to /home/marianna/nltk_data...
#        |   Package qc is already up-to-date!
#        | Downloading package reuters to /home/marianna/nltk_data...
#        |   Package reuters is already up-to-date!
#        | Downloading package rte to /home/marianna/nltk_data...
#        |   Package rte is already up-to-date!
#        | Downloading package semcor to /home/marianna/nltk_data...
#        |   Package semcor is already up-to-date!
#        | Downloading package senseval to /home/marianna/nltk_data...
#        |   Package senseval is already up-to-date!
#        | Downloading package sentiwordnet to
#        |     /home/marianna/nltk_data...
#        |   Package sentiwordnet is already up-to-date!
#        | Downloading package sentence_polarity to
#        |     /home/marianna/nltk_data...
#        |   Package sentence_polarity is already up-to-date!
#        | Downloading package shakespeare to
#        |     /home/marianna/nltk_data...
#        |   Package shakespeare is already up-to-date!
#        | Downloading package sinica_treebank to
#        |     /home/marianna/nltk_data...
#        |   Package sinica_treebank is already up-to-date!
#        | Downloading package smultron to /home/marianna/nltk_data...
#        |   Package smultron is already up-to-date!
#        | Downloading package state_union to
#        |     /home/marianna/nltk_data...
#        |   Package state_union is already up-to-date!
#        | Downloading package stopwords to /home/marianna/nltk_data...
#        |   Package stopwords is already up-to-date!
#        | Downloading package subjectivity to
#        |     /home/marianna/nltk_data...
#        |   Package subjectivity is already up-to-date!
#        | Downloading package swadesh to /home/marianna/nltk_data...
#        |   Package swadesh is already up-to-date!
#        | Downloading package switchboard to
#        |     /home/marianna/nltk_data...
#        |   Package switchboard is already up-to-date!
#        | Downloading package timit to /home/marianna/nltk_data...
#        |   Package timit is already up-to-date!
#        | Downloading package toolbox to /home/marianna/nltk_data...
#        |   Package toolbox is already up-to-date!
#        | Downloading package treebank to /home/marianna/nltk_data...
#        |   Package treebank is already up-to-date!
#        | Downloading package twitter_samples to
#        |     /home/marianna/nltk_data...
#        |   Package twitter_samples is already up-to-date!
#        | Downloading package udhr to /home/marianna/nltk_data...
#        |   Package udhr is already up-to-date!
#        | Downloading package udhr2 to /home/marianna/nltk_data...
#        |   Package udhr2 is already up-to-date!
#        | Downloading package unicode_samples to
#        |     /home/marianna/nltk_data...
#        |   Package unicode_samples is already up-to-date!
#        | Downloading package universal_treebanks_v20 to
#        |     /home/marianna/nltk_data...
#        |   Package universal_treebanks_v20 is already up-to-date!
#        | Downloading package verbnet to /home/marianna/nltk_data...
#        |   Package verbnet is already up-to-date!
#        | Downloading package verbnet3 to /home/marianna/nltk_data...
#        |   Package verbnet3 is already up-to-date!
#        | Downloading package webtext to /home/marianna/nltk_data...
#        |   Package webtext is already up-to-date!
#        | Downloading package wordnet to /home/marianna/nltk_data...
#        |   Package wordnet is already up-to-date!
#        | Downloading package wordnet_ic to /home/marianna/nltk_data...
#        |   Package wordnet_ic is already up-to-date!
#        | Downloading package words to /home/marianna/nltk_data...
#        |   Package words is already up-to-date!
#        | Downloading package ycoe to /home/marianna/nltk_data...
#        |   Package ycoe is already up-to-date!
#        | Downloading package rslp to /home/marianna/nltk_data...
#        |   Package rslp is already up-to-date!
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /home/marianna/nltk_data...
#        |   Package maxent_treebank_pos_tagger is already up-to-date!
#        | Downloading package universal_tagset to
#        |     /home/marianna/nltk_data...
#        |   Package universal_tagset is already up-to-date!
#        | Downloading package maxent_ne_chunker to
#        |     /home/marianna/nltk_data...
#        |   Package maxent_ne_chunker is already up-to-date!
#        | Downloading package punkt to /home/marianna/nltk_data...
#        |   Package punkt is already up-to-date!
#        | Downloading package book_grammars to
#        |     /home/marianna/nltk_data...
#        |   Package book_grammars is already up-to-date!
#        | Downloading package sample_grammars to
#        |     /home/marianna/nltk_data...
#        |   Package sample_grammars is already up-to-date!
#        | Downloading package spanish_grammars to
#        |     /home/marianna/nltk_data...
#        |   Package spanish_grammars is already up-to-date!
#        | Downloading package basque_grammars to
#        |     /home/marianna/nltk_data...
#        |   Package basque_grammars is already up-to-date!
#        | Downloading package large_grammars to
#        |     /home/marianna/nltk_data...
#        |   Package large_grammars is already up-to-date!
#        | Downloading package tagsets to /home/marianna/nltk_data...
#        |   Package tagsets is already up-to-date!
#        | Downloading package snowball_data to
#        |     /home/marianna/nltk_data...
#        |   Package snowball_data is already up-to-date!
#        | Downloading package bllip_wsj_no_aux to
#        |     /home/marianna/nltk_data...
#        |   Package bllip_wsj_no_aux is already up-to-date!
#        | Downloading package word2vec_sample to
#        |     /home/marianna/nltk_data...
#        |   Package word2vec_sample is already up-to-date!
#        | Downloading package panlex_swadesh to
#        |     /home/marianna/nltk_data...
#        |   Package panlex_swadesh is already up-to-date!
#        | Downloading package mte_teip5 to /home/marianna/nltk_data...
#        |   Package mte_teip5 is already up-to-date!
#        | Downloading package averaged_perceptron_tagger to
#        |     /home/marianna/nltk_data...
#        |   Package averaged_perceptron_tagger is already up-to-date!
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /home/marianna/nltk_data...
#        |   Package averaged_perceptron_tagger_ru is already up-to-
#        |       date!
#        | Downloading package perluniprops to
#        |     /home/marianna/nltk_data...
#        |   Package perluniprops is already up-to-date!
#        | Downloading package nonbreaking_prefixes to
#        |     /home/marianna/nltk_data...
#        |   Package nonbreaking_prefixes is already up-to-date!
#        | Downloading package vader_lexicon to
#        |     /home/marianna/nltk_data...
#        |   Package vader_lexicon is already up-to-date!
#        | Downloading package porter_test to
#        |     /home/marianna/nltk_data...
#        |   Package porter_test is already up-to-date!
#        | Downloading package wmt15_eval to /home/marianna/nltk_data...
#        |   Package wmt15_eval is already up-to-date!
#        | Downloading package mwa_ppdb to /home/marianna/nltk_data...
#        |   Package mwa_ppdb is already up-to-date!
#        |
#      Done downloading collection all
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# ## Preprocess data

# %%
#unites both sets to prepare them

punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

for entry in df_all:
    # remove uppercase letters
    entry = entry.lower()
    # remove numbers
    entry = re.sub(r'\d+', '', entry)
    # remove punctuation
    entry = re.sub(r'[^\w\s]','', entry)
    # remove whitespaces
    entry = entry.strip()
    # remove stopwords and tokenize
    tokens = word_tokenize(entry)
    entry = [i for i in tokens if not i in stop]
df_all
# Out:
#         id                                title  \
# 0        0  Bargain calls widen Softbank loss\n
# 1        1    S&N extends Indian beer venture\n
# 2        2   News Corp makes $5.4bn Fox offer\n
# 3        3    China now top trader with Japan\n
# 4        4   Asian quake hits European shares\n
# ...    ...                                  ...
# 2220  2220         Concerns over Windows ATMs\n
# 2221  2221  Britons growing 'digitally obese'\n
# 2222  2222    Online games play with politics\n
# 2223  2223    Mobiles rack up 20 years of use\n
# 2224  2224  Nintendo handheld given Euro date\n
#
#                                                 content  category
# 0     \nJapanese communications firm Softbank has wi...  business
# 1     \nThe UK's biggest brewer, Scottish and Newcas...  business
# 2     \nNews Corporation is seeking to buy out minor...  business
# 3     \nChina overtook the US to become Japan's bigg...  business
# 4     \nShares in Europe's leading reinsurers and tr...  business
# ...                                                 ...       ...
# 2220  \nCash machine networks could soon be more sus...      tech
# 2221  \nGadget lovers are so hungry for digital data...      tech
# 2222  \nAfter bubbling under for some time, online g...      tech
# 2223  \nMobile phones in the UK are celebrating thei...      tech
# 2224  \nNintendo's new handheld console, the DS, wil...      tech
#
# [2225 rows x 4 columns]

# %%
from sklearn import preprocessing

x = preprocessing.OneHotEncoder().fit_transform(df_all.drop('category', axis=1))
y = df_all['category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %% [markdown]
# ## SVM

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix

param_grid = {'C': [0.1,1, 10, 100], 'gamma': [1,0.1,0.01,0.001],'kernel': ['rbf', 'linear']}

grid = GridSearchCV(svm.SVC(), param_grid, scoring = ['accuracy', 'precision_micro', 'recall_micro', 'f1_micro' ], 
                       cv = 10,
                       refit= 'accuracy',
                       verbose = 1,
                       n_jobs = -1)

clf = svm.SVC(kernel = 'linear')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)

print(confusion_matrix(y_test,y_pred))
print()
print(classification_report(y_test,y_pred))
# Out:
# [[102   0   0   0   0]
#  [ 69   9   0   0   0]
#  [ 70   0   3   0   0]
#  [ 99   0   0   9   0]
#  [ 55   0   0   0  29]]
#
#                precision    recall  f1-score   support
#
#      business       0.26      1.00      0.41       102
# entertainment       1.00      0.12      0.21        78
#      politics       1.00      0.04      0.08        73
#         sport       1.00      0.08      0.15       108
#          tech       1.00      0.35      0.51        84
#
#      accuracy                           0.34       445
#     macro avg       0.85      0.32      0.27       445
#  weighted avg       0.83      0.34      0.28       445

# %% [markdown]
# ## Random forests

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=100)

clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

print(confusion_matrix(y_test,y_pred))
print()
print(classification_report(y_test,y_pred))
# Out:
# [[102   0   0   0   0]
#  [ 75   3   0   0   0]
#  [ 71   0   2   0   0]
#  [102   0   0   6   0]
#  [ 76   0   0   0   8]]
#
#                precision    recall  f1-score   support
#
#      business       0.24      1.00      0.39       102
# entertainment       1.00      0.04      0.07        78
#      politics       1.00      0.03      0.05        73
#         sport       1.00      0.06      0.11       108
#          tech       1.00      0.10      0.17        84
#
#      accuracy                           0.27       445
#     macro avg       0.85      0.24      0.16       445
#  weighted avg       0.83      0.27      0.17       445

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
import numpy

gnb = GaussianNB()
gnb.fit(x_train.toarray(), y_train)

y_pred = gnb.predict(x_test.toarray())

print(confusion_matrix(y_test,y_pred))
print()
print(classification_report(y_test,y_pred))
# Out:
# [[ 3  0  0  0 99]
#  [ 0  9  0  0 69]
#  [ 0  0  3  0 70]
#  [ 0  0  0  9 99]
#  [ 0  0  0  0 84]]
#
#                precision    recall  f1-score   support
#
#      business       1.00      0.03      0.06       102
# entertainment       1.00      0.12      0.21        78
#      politics       1.00      0.04      0.08        73
#         sport       1.00      0.08      0.15       108
#          tech       0.20      1.00      0.33        84
#
#      accuracy                           0.24       445
#     macro avg       0.84      0.25      0.17       445
#  weighted avg       0.85      0.24      0.16       445
